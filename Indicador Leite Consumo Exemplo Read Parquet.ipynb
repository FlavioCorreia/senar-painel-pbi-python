# %%
import pandas as pd
import sqlalchemy
import datetime
pd.set_option('display.max_columns', 200)
from IPython.display import display
import os

# %%
df_mensal = pd.read_parquet('files/sisateg_rel_indicador_leite_mensal.parquet')
df_mensal.shape
# Out:
# (1077948, 49)

# %%
df_mensal.head(3)
# Out:
#                                 index  type       id  score  \
# 0  sisateg_rel_indicador_leite_mensal  _doc  3653318    1.0
# 1  sisateg_rel_indicador_leite_mensal  _doc  3814338    1.0
# 2  sisateg_rel_indicador_leite_mensal  _doc  2800301    1.0
#
#    jurossobrecapital  idpropriedade         dtalteracaovisita  \
# 0                0.0         211135  2024-01-19T15:49:17.317Z
# 1                0.0         211135  2024-01-19T15:49:17.350Z
# 2                0.0         211150  2024-01-19T15:49:17.310Z
#
#    precomedioleite ufregional dtexclusaovisita  \
# 0             1.65         BA             None
# 1             1.80         BA             None
# 2             2.00         BA             None
#
#    concentradopelarendabrutaatividade  idregional    regiao  \
# 0                                0.11          10  NORDESTE
# 1                                0.09          10  NORDESTE
# 2                                0.00          10  NORDESTE
#
# ...
